# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder

# %%
data = pd.read_csv('/content/Bank_customer_data.csv')

print(data.head())
# Out:
#    ID  Age  Experience  Income  Zipcode  Family    CCAvg  Education  Mortgage  \
# 0   1   39          14  127000    49560       1   567.28          2     36000
# 1   2   36           0   72000    63865       1  3927.17          1    341000
# 2   3   37           5  147000    56686       2   369.79          1    326000
# 3   4   55           4  199000    85910       4  3847.52          3    406000
# 4   5   45          17  177000    14675       1    26.63          2    424000
#
#    Securities Account  CD Account  Online  CreditCard  Personal Loan
# 0                   1           0       1           0              1
# 1                   1           0       0           0              0
# 2                   0           0       0           1              0
# 3                   0           0       0           0              0
# 4                   0           0       0           0              0

# %%
# Drop unnecessary columns
data.drop(columns=['ID', 'Zipcode'], inplace=True)

# Define target variable (y) and features (X)
y = data['Personal Loan']
X = data.drop(columns=['Personal Loan'])

# Encode categorical variable (Education)
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_edu = pd.DataFrame(encoder.fit_transform(data[['Education']]), columns=encoder.get_feature_names_out(['Education']))

# Drop original 'Education' column and add encoded values
X = X.drop(columns=['Education'])
X = pd.concat([X, encoded_edu], axis=1)

# %%
# Scale numerical features
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# Split data into training & testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print(f"Training Data Shape: {X_train.shape}, Test Data Shape: {X_test.shape}")
# Out:
# Training Data Shape: (400, 12), Test Data Shape: (100, 12)

# %%
# Define the model

model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model

test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.2f}")
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8434 - loss: 0.5465 - val_accuracy: 0.8400 - val_loss: 0.4633
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8450 - loss: 0.4411 - val_accuracy: 0.8400 - val_loss: 0.4409
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8395 - loss: 0.4274 - val_accuracy: 0.8400 - val_loss: 0.4423
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8463 - loss: 0.4051 - val_accuracy: 0.8400 - val_loss: 0.4359
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8475 - loss: 0.3879 - val_accuracy: 0.8400 - val_loss: 0.4291
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8458 - loss: 0.3905 - val_accuracy: 0.8400 - val_loss: 0.4284
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8555 - loss: 0.3677 - val_accuracy: 0.8400 - val_loss: 0.4264
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8528 - loss: 0.3650 - val_accuracy: 0.8400 - val_loss: 0.4240
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8816 - loss: 0.3128 - val_accuracy: 0.8400 - val_loss: 0.4260
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8611 - loss: 0.3225 - val_accuracy: 0.8400 - val_loss: 0.4216
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8505 - loss: 0.3553 - val_accuracy: 0.8400 - val_loss: 0.4233
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8605 - loss: 0.3355 - val_accuracy: 0.8400 - val_loss: 0.4241
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8599 - loss: 0.3224 - val_accuracy: 0.8400 - val_loss: 0.4252
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8381 - loss: 0.3612 - val_accuracy: 0.8400 - val_loss: 0.4281
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8436 - loss: 0.3458 - val_accuracy: 0.8400 - val_loss: 0.4326
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8266 - loss: 0.3543 - val_accuracy: 0.8400 - val_loss: 0.4328
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.